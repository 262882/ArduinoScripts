# %%
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# Omron D6F 50A6 flow meter properties

# %%
Vout = np.array([1, 2.45, 3.51, 4.20, 4.66, 5.00])
Flow = np.array([0,   10,   20,   30,   40,   50])

# %% [markdown]
# Model spec and fit

# %%
deg = 2
coefficients = np.polyfit(Vout, Flow, deg)
coefficients
# Out:
# array([ 2.68487688, -4.22510972,  2.21685325])

# %% [markdown]
# Plot results

# %%
plt.figure()
plt.scatter(Vout,Flow)
plt.plot(model_x,model_y,color="black")
plt.title("Polynomial regression with degree "+str(deg))
plt.xlim(xmin=1)
plt.show()
